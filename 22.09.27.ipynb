# %%
# !pip install sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=3748f1e98f24be95afb676b96768bba54fe64beba957fd4bb7717c83ede96101
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built sklearn
# ...

# %%
from sklearn import datasets

d= datasets.load_iris()
print(d.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
for i in range(0, len(d.data)):
    print(i+1,d.data[i],d.target[i])
# Out:
# 1 [5.1 3.5 1.4 0.2] 0
# 2 [4.9 3.  1.4 0.2] 0
# 3 [4.7 3.2 1.3 0.2] 0
# 4 [4.6 3.1 1.5 0.2] 0
# 5 [5.  3.6 1.4 0.2] 0
# 6 [5.4 3.9 1.7 0.4] 0
# 7 [4.6 3.4 1.4 0.3] 0
# 8 [5.  3.4 1.5 0.2] 0
# 9 [4.4 2.9 1.4 0.2] 0
# 10 [4.9 3.1 1.5 0.1] 0
# 11 [5.4 3.7 1.5 0.2] 0
# 12 [4.8 3.4 1.6 0.2] 0
# 13 [4.8 3.  1.4 0.1] 0
# 14 [4.3 3.  1.1 0.1] 0
# 15 [5.8 4.  1.2 0.2] 0
# 16 [5.7 4.4 1.5 0.4] 0
# 17 [5.4 3.9 1.3 0.4] 0
# 18 [5.1 3.5 1.4 0.3] 0
# 19 [5.7 3.8 1.7 0.3] 0
# 20 [5.1 3.8 1.5 0.3] 0
# 21 [5.4 3.4 1.7 0.2] 0
# 22 [5.1 3.7 1.5 0.4] 0
# 23 [4.6 3.6 1.  0.2] 0
# 24 [5.1 3.3 1.7 0.5] 0
# 25 [4.8 3.4 1.9 0.2] 0
# 26 [5.  3.  1.6 0.2] 0
# 27 [5.  3.4 1.6 0.4] 0
# 28 [5.2 3.5 1.5 0.2] 0
# 29 [5.2 3.4 1.4 0.2] 0
# 30 [4.7 3.2 1.6 0.2] 0
# 31 [4.8 3.1 1.6 0.2] 0
# 32 [5.4 3.4 1.5 0.4] 0
# 33 [5.2 4.1 1.5 0.1] 0
# 34 [5.5 4.2 1.4 0.2] 0
# 35 [4.9 3.1 1.5 0.2] 0
# 36 [5.  3.2 1.2 0.2] 0
# 37 [5.5 3.5 1.3 0.2] 0
# 38 [4.9 3.6 1.4 0.1] 0
# 39 [4.4 3.  1.3 0.2] 0
# 40 [5.1 3.4 1.5 0.2] 0
# ...

# %%
from sklearn import svm

s = svm.SVC(gamma=0.1, C=10)
s.fit(d.data, d.target)
new_d = [[6.4,3.2,6.0,2.5],[7.1,3.1,4.7,1.35]]

res=s.predict(new_d)
print("새로운 2개 샘플의 부류는", res)
# Out:
# 새로운 2개 샘플의 부류는 [2 1]

# %%
\vzs = svm.SVC(gamma=0.1, C=10)
s.fit(d.data, d.target)
new_d = [[4.1, 3.5, 1.4, 0.2],[5.1,3.1,7,2.35]]

res=s.predict(new_d)
print("새로운 2개 샘플의 부류는", res)
# Out:
# 새로운 2개 샘플의 부류는 [0 2]

# %% [markdown]
# 표본추출편향 : 추출과정에서 체계적인 경향이 개입되어 모집단에서 편향된 표본만 추출됨
#
# 가구편향 : 모집단의 부분집단 단위에서 적은집단이 작고 많은 집단보다 적게 추출되는 경우
#
# 무응답편향 : 응답하는 사람들과 응답하지 않는 사람들에 체계적인 차이가 있는 경우
#
# 응답편향 : 응답자의 심리적 이슈에 의해 영향을 받는경우
#
# 생존자 편향
